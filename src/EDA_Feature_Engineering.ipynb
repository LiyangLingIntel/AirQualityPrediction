# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import os
from utils import *
from settings import station_locale, data_root, output_folder, report_folder

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import LabelEncoder

# %%
data_folder = '../outputs/'
report_folder = '../report_rc/'

# %% [markdown]
# ## Load Data & EDA & Processing

# %%
aq_df = pd.read_csv(os.path.join(data_folder, 'air_quality_no_duplicates.zip'))
gw_df = pd.read_csv(os.path.join(data_folder, 'grid_weather_processed.zip'))
ow_df = pd.read_csv(os.path.join(data_folder, 'ob_weather_processded.zip'))

# %%
aq_df = aq_df.drop(['Unnamed: 0'], axis=1)
gw_df = gw_df.drop(['Unnamed: 0'], axis=1)
ow_df = ow_df.drop(['Unnamed: 0'], axis=1)

# %%
aq_df.head()
# Out:
#         station_id  PM2.5   PM10    NO2   CO   O3  SO2        CO3  longitude  \
# 0  aotizhongxin_aq  453.0  467.0  156.0  7.2  3.0  9.0  29.428746    116.397
# 1  aotizhongxin_aq  417.0  443.0  143.0  6.8  2.0  8.0  37.000000    116.397
# 2  aotizhongxin_aq  395.0  467.0  141.0  6.9  3.0  8.0  40.285393    116.397
# 3  aotizhongxin_aq  420.0  484.0  139.0  7.4  3.0  9.0  28.142929    116.397
# 4  aotizhongxin_aq  453.0  520.0  157.0  7.6  4.0  9.0  38.856791    116.397
#
#    latitude           local_time        date      time  solar_term  \
# 0    39.982  2017-01-01 22:00:00  2017-01-01  22:00:00           7
# 1    39.982  2017-01-01 23:00:00  2017-01-01  23:00:00           7
# 2    39.982  2017-01-02 00:00:00  2017-01-02  00:00:00           7
# 3    39.982  2017-01-02 01:00:00  2017-01-02  01:00:00           7
# 4    39.982  2017-01-02 02:00:00  2017-01-02  02:00:00           7
#
#    time_label  NearTraffic  Others  SubUrban  Urban  datetime_label
# 0           4            0       0         0      1               0
# 1           3            0       0         0      1               1
# 2           2            0       0         0      1               2
# 3           1            0       0         0      1               3
# 4           0            0       0         0      1               4

# %%
gw_df.head()
# Out:
#          station_id  longitude  latitude           local_time  temperature  \
# 0  beijing_grid_000      115.0      39.0  2017-01-01 08:00:00        -5.47
# 1  beijing_grid_001      115.0      39.1  2017-01-01 08:00:00        -5.53
# 2  beijing_grid_002      115.0      39.2  2017-01-01 08:00:00        -5.70
# 3  beijing_grid_003      115.0      39.3  2017-01-01 08:00:00        -5.88
# 4  beijing_grid_004      115.0      39.4  2017-01-01 08:00:00        -5.34
#
#    pressure  humidity  wind_direction  wind_speed        date      time  \
# 0    984.73     76.60           53.71        3.53  2017-01-01  08:00:00
# 1    979.33     75.40           43.59        3.11  2017-01-01  08:00:00
# 2    963.14     71.80            0.97        2.75  2017-01-01  08:00:00
# 3    946.94     68.20          327.65        3.84  2017-01-01  08:00:00
# 4    928.80     58.81          317.85        6.14  2017-01-01  08:00:00
#
#    solar_term  time_label  datetime_label
# 0           7           6               0
# 1           7           6               0
# 2           7           6               0
# 3           7           6               0
# 4           7           6               0

# %%
ow_df.head()
# Out:
#    station_id   longitude   latitude           local_time  temperature  \
# 0  shunyi_meo  116.615278  40.126667  2017-01-31 00:00:00         -1.7
# 1  shunyi_meo  116.615278  40.126667  2017-01-31 01:00:00         -3.5
# 2  shunyi_meo  116.615278  40.126667  2017-01-31 02:00:00         -3.7
# 3  shunyi_meo  116.615278  40.126667  2017-01-31 03:00:00         -3.9
# 4  shunyi_meo  116.615278  40.126667  2017-01-31 04:00:00         -4.1
#
#    pressure  humidity  wind_direction  wind_speed      weather        date  \
# 0    1028.7      15.0           215.0         1.6  Sunny/clear  2017-01-31
# 1    1028.4      24.0            16.0         1.0         Haze  2017-01-31
# 2    1028.1      27.0            32.0         1.1         Haze  2017-01-31
# 3    1027.6      27.0            21.0         0.9         Haze  2017-01-31
# 4    1026.7      26.0            17.0         1.1         Haze  2017-01-31
#
#        time  solar_term  time_label  datetime_label
# 0  00:00:00           9           2               0
# 1  01:00:00           9           1               1
# 2  02:00:00           9           0               2
# 3  03:00:00           9           1               3
# 4  04:00:00           9           2               4

# %%
df_indicator = gw_df[['longitude', 'latitude', 'local_time', 'temperature', 'pressure', 'humidity']]
df_indicator = df_indicator.append(ow_df[['longitude', 'latitude', 'local_time', 'temperature', 'pressure', 'humidity']])

# %%
df_indicator.head()
# Out:
#    longitude  latitude           local_time  temperature  pressure  humidity  \
# 0      115.0      39.0  2017-01-01 08:00:00        -5.47    984.73     76.60
# 1      115.0      39.1  2017-01-01 08:00:00        -5.53    979.33     75.40
# 2      115.0      39.2  2017-01-01 08:00:00        -5.70    963.14     71.80
# 3      115.0      39.3  2017-01-01 08:00:00        -5.88    946.94     68.20
# 4      115.0      39.4  2017-01-01 08:00:00        -5.34    928.80     58.81
#
#    datetime_label
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
datetime_labeler = LabelEncoder()
df_indicator['datetime_label'] = datetime_labeler.fit_transform(df_indicator['local_time'])
aq_df['datetime_label'] = datetime_labeler.transform(aq_df['local_time'])

# %%
neibours = 7
weight = 'distance' # 'uniform', 'distance'

train_x = df_indicator[['longitude', 'latitude', 'datetime_label']]
train_y = df_indicator[['temperature']]
knn_temperature = KNeighborsRegressor(n_neighbors=neibours, weights=weight)
knn_temperature.fit(train_x, train_y)

train_x = df_indicator[['longitude', 'latitude', 'datetime_label']]
train_y = df_indicator[['pressure']]
knn_pressure = KNeighborsRegressor(n_neighbors=neibours, weights=weight)
knn_pressure.fit(train_x, train_y)

train_x = df_indicator[['longitude', 'latitude', 'datetime_label']]
train_y = df_indicator[['humidity']]
knn_humidity = KNeighborsRegressor(n_neighbors=neibours, weights=weight)
knn_humidity.fit(train_x, train_y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=7, p=2,
#           weights='distance')

# %%
aq_df['temperature'] = knn_temperature.predict(aq_df[['longitude', 'latitude', 'datetime_label']])
aq_df['pressure'] = knn_pressure.predict(aq_df[['longitude', 'latitude', 'datetime_label']])
aq_df['humidity'] = knn_humidity.predict(aq_df[['longitude', 'latitude', 'datetime_label']])

# %%
indicator = ['temperature', 'pressure', 'humidity']
temp = aq_df.query('station_id=="aotizhongxin_aq"')

plt.figure(figsize=(6,8), dpi=200)
i = 1
for indic in indicator:
    plt.subplot(3,1,i)
    plt.plot(temp['datetime_label'], temp[indic])
    plt.title(f'aotizhongxin {indic}')
    plt.ylabel(indic)
    plt.xlabel('datetime_label')
    plt.xticks(rotation=90)
    i+=1
plt.tight_layout()
plt.savefig(os.path.join(report_folder, 'atzx_weather_indocators.png'))
plt.show()

# %%
indicator = ['PM2.5', 'PM10', 'O3']
temp = aq_df.query('station_id=="aotizhongxin_aq" and datetime_label<720')

plt.figure(figsize=(6,8), dpi=200)
i = 1
for indic in indicator:
    plt.subplot(3,1,i)
    plt.plot(temp['datetime_label'], temp[indic])
    plt.title(f'aotizhongxin {indic}')
    plt.ylabel(indic)
    plt.xlabel('datetime_label')
    plt.xticks(rotation=90)
    i+=1
plt.tight_layout()
plt.savefig(os.path.join(report_folder, 'atzx_air_quanlities.png'))
plt.show()

# %%
aq_df
# Out:
#                station_id       PM2.5         PM10         NO2        CO  \
# 0         aotizhongxin_aq  453.000000   467.000000  156.000000  7.200000
# 1         aotizhongxin_aq  417.000000   443.000000  143.000000  6.800000
# 2         aotizhongxin_aq  395.000000   467.000000  141.000000  6.900000
# 3         aotizhongxin_aq  420.000000   484.000000  139.000000  7.400000
# 4         aotizhongxin_aq  453.000000   520.000000  157.000000  7.600000
# 5         aotizhongxin_aq  429.000000    95.428571  141.000000  6.500000
# 6         aotizhongxin_aq  211.000000   111.571429  110.000000  3.300000
# 7         aotizhongxin_aq  116.000000   103.000000   87.000000  2.200000
# 8         aotizhongxin_aq   51.000000    74.000000   58.000000  1.300000
# 9         aotizhongxin_aq   38.000000   115.142857   55.000000  1.100000
# 10        aotizhongxin_aq   21.000000    77.142857   40.000000  0.700000
# 11        aotizhongxin_aq   16.000000   121.428571   40.000000  0.800000
# 12        aotizhongxin_aq   23.000000    86.142857   42.000000  0.700000
# 13        aotizhongxin_aq   18.000000    68.714286   30.000000  0.600000
# 14        aotizhongxin_aq   58.000000   247.000000   76.000000  2.400000
# 15        aotizhongxin_aq  176.000000    67.714286   99.000000  0.300000
# 16        aotizhongxin_aq  109.000000   211.000000   86.000000  2.600000
# 17        aotizhongxin_aq  267.000000    67.714286  125.000000  4.200000
# 18        aotizhongxin_aq  260.000000    35.428571  115.000000  3.900000
# 19        aotizhongxin_aq  212.000000    68.714286  112.000000  3.600000
# 20        aotizhongxin_aq  183.000000    86.142857  111.000000  0.300000
# 21        aotizhongxin_aq  136.000000   121.428571   89.000000  2.300000
# 22        aotizhongxin_aq  137.000000    77.142857   89.000000  2.200000
# 23        aotizhongxin_aq  125.000000   115.142857   90.000000  2.100000
# 24        aotizhongxin_aq  153.000000    74.000000  108.000000  2.500000
# 25        aotizhongxin_aq  165.000000   103.000000  126.000000  3.100000
# 26        aotizhongxin_aq  225.000000   111.571429  148.000000  4.900000
# 27        aotizhongxin_aq  275.000000    95.428571  158.000000  6.400000
# 28        aotizhongxin_aq  293.000000   104.857143  155.000000  6.400000
# 29        aotizhongxin_aq  293.000000    95.428571  153.000000  6.200000
# ...                   ...         ...          ...         ...       ...
# 377235    nongzhanguan_aq   61.000000   279.000000   40.000000  0.400000
# 377236          wanliu_aq   52.000000   181.000000   56.000000  0.400000
# 377237      beibuxinqu_aq   79.000000   541.000000   32.000000  0.600000
# 377238       zhiwuyuan_aq   17.571429    74.857143   24.285714  0.371429
# 377239  fengtaihuayuan_aq   63.000000   260.000000   45.000000  0.600000
# 377240         yungang_aq   41.000000   127.000000   24.000000  0.500000
# 377241         gucheng_aq   72.000000   296.000000   30.000000  0.500000
# 377242        fangshan_aq   44.000000   144.000000   56.000000  0.600000
# 377243          daxing_aq   54.000000   151.000000   70.000000  0.300000
# 377244        yizhuang_aq   42.000000    96.000000   80.000000  0.800000
# 377245        tongzhou_aq   41.000000   102.000000   56.000000  0.600000
# 377246          shunyi_aq   37.000000    52.000000   30.000000  0.800000
# 377247       pingchang_aq   72.000000   587.000000   24.000000  0.300000
# 377248       mentougou_aq   49.000000   435.000000   27.000000  0.500000
# 377249          pinggu_aq   32.000000    59.000000   24.000000  0.600000
# 377250         huairou_aq   32.000000    61.000000   20.000000  0.600000
# 377251           miyun_aq   53.000000   202.000000   19.000000  0.500000
# 377252          yanqin_aq   83.000000   343.000000   49.000000  0.600000
# 377253        dingling_aq   76.000000   418.000000   17.000000  0.300000
# 377254        badaling_aq  121.000000  1188.000000   36.000000  0.300000
# 377255     miyunshuiku_aq   42.000000    49.000000   17.000000  0.600000
# 377256      donggaocun_aq   23.000000    42.000000   13.000000  0.400000
# 377257      yongledian_aq   31.000000    95.000000   75.000000  0.900000
# 377258            yufa_aq   51.000000   117.000000   62.000000  0.600000
# 377259         liulihe_aq   48.000000   124.000000   37.000000  0.600000
# 377260         qianmen_aq   64.000000   316.000000   63.000000  0.500000
# 377261  yongdingmennei_aq   55.000000   298.000000  102.000000  0.600000
# 377262     xizhimenbei_aq  185.000000   428.000000   72.000000  0.400000
# 377263      nansanhuan_aq   54.000000   228.000000   61.000000  0.400000
# 377264      dongsihuan_aq   53.000000   173.000000   78.000000  0.500000
#
#                O3        SO2         CO3  longitude  latitude    ...      \
# 0        3.000000   9.000000   29.428746    116.397    39.982    ...
# 1        2.000000   8.000000   37.000000    116.397    39.982    ...
# 2        3.000000   8.000000   40.285393    116.397    39.982    ...
# 3        3.000000   9.000000   28.142929    116.397    39.982    ...
# 4        4.000000   9.000000   38.856791    116.397    39.982    ...
# 5        3.000000   9.000000   28.142929    116.397    39.982    ...
# 6       19.714286  11.000000   40.285393    116.397    39.982    ...
# 7        4.000000  13.000000   37.000000    116.397    39.982    ...
# 8       26.000000  14.000000   29.428746    116.397    39.982    ...
# 9       28.000000  14.000000   52.428571    116.397    39.982    ...
# 10      42.000000  16.000000   71.285652    116.397    39.982    ...
# 11      44.000000  18.000000   71.142877    116.397    39.982    ...
# 12      45.000000  17.000000   76.857143    116.397    39.982    ...
# 13      59.000000  14.000000   79.000000    116.397    39.982    ...
# 14      46.000000  12.000000  111.714286    116.397    39.982    ...
# 15      42.000000  17.000000  102.000102    116.397    39.982    ...
# 16      58.000000  14.000000  127.285785    116.397    39.982    ...
# 17      53.000000  19.000000  102.000102    116.397    39.982    ...
# 18      56.000000  18.000000  111.714286    116.397    39.982    ...
# 19      50.000000  14.000000   79.000000    116.397    39.982    ...
# 20      33.000000  14.000000   76.857143    116.397    39.982    ...
# 21      41.000000  14.000000   71.142877    116.397    39.982    ...
# 22      35.000000  13.000000   71.285652    116.397    39.982    ...
# 23      28.000000  13.000000   52.428571    116.397    39.982    ...
# 24      13.000000  14.000000   29.428746    116.397    39.982    ...
# 25       2.000000  14.000000   37.000000    116.397    39.982    ...
# 26       4.000000  23.000000   40.285393    116.397    39.982    ...
# 27       7.000000  28.000000   28.142929    116.397    39.982    ...
# 28       5.000000  17.000000   38.856791    116.397    39.982    ...
# 29       5.000000  16.000000   28.142929    116.397    39.982    ...
# ...           ...        ...         ...        ...       ...    ...
# 377235  57.142857   3.000000   36.000000    116.461    39.937    ...
# 377236  45.142857   5.000000   11.000000    116.287    39.987    ...
# 377237  86.857143   2.000000   37.000000    116.174    40.090    ...
# 377238  63.571429   2.571429   49.571429    116.207    40.002    ...
# 377239  35.000000   2.000000   32.000000    116.279    39.863    ...
# 377240  65.571429   2.000000   33.000000    116.146    39.824    ...
# 377241  52.714286   2.000000   51.000000    116.184    39.914    ...
# 377242  57.571429   2.000000   26.000000    116.136    39.742    ...
# 377243  60.571429   2.000000   15.000000    116.404    39.718    ...
# 377244  46.142857   2.000000    4.000000    116.506    39.795    ...
# 377245  28.714286   3.000000   14.000000    116.663    39.886    ...
# 377246  52.428571   3.000000   43.000000    116.655    40.127    ...
# 377247  52.000000   2.000000   54.000000    116.230    40.217    ...
# 377248  77.857143   2.000000   57.000000    116.106    39.937    ...
# 377249  66.714286   2.000000   53.000000    117.100    40.143    ...
# 377250  67.142857   2.000000   45.000000    116.628    40.328    ...
# 377251  72.571429   2.000000   57.000000    116.832    40.370    ...
# 377252  54.285714   2.000000    2.000000    115.972    40.453    ...
# 377253  68.571429   2.000000   63.000000    116.220    40.292    ...
# 377254  65.285714   2.000000   39.000000    115.988    40.365    ...
# 377255  95.571429   2.000000   48.000000    116.911    40.499    ...
# 377256  54.857143   2.000000   52.000000    117.120    40.100    ...
# 377257  62.714286   3.000000    4.000000    116.783    39.712    ...
# 377258  34.571429   2.000000   11.000000    116.300    39.520    ...
# 377259  41.857143   2.000000    7.000000    116.000    39.580    ...
# 377260  48.857143   3.000000   25.000000    116.395    39.899    ...
# 377261  49.571429   6.000000   24.000000    116.394    39.876    ...
# 377262  59.428571   3.000000   15.000000    116.349    39.954    ...
# 377263  21.285714   2.000000   23.000000    116.368    39.856    ...
# 377264  49.000000   5.000000    2.000000    116.483    39.939    ...
#
#        solar_term time_label NearTraffic  Others  SubUrban  Urban  \
# 0               7          4           0       0         0      1
# 1               7          3           0       0         0      1
# 2               7          2           0       0         0      1
# 3               7          1           0       0         0      1
# 4               7          0           0       0         0      1
# 5               7          1           0       0         0      1
# 6               7          2           0       0         0      1
# 7               7          3           0       0         0      1
# 8               7          4           0       0         0      1
# 9               7          5           0       0         0      1
# 10              7          6           0       0         0      1
# 11              7          7           0       0         0      1
# 12              7          8           0       0         0      1
# 13              7          9           0       0         0      1
# 14              7         10           0       0         0      1
# 15              7         11           0       0         0      1
# 16              7         12           0       0         0      1
# 17              7         11           0       0         0      1
# 18              7         10           0       0         0      1
# 19              7          9           0       0         0      1
# 20              7          8           0       0         0      1
# 21              7          7           0       0         0      1
# 22              7          6           0       0         0      1
# 23              7          5           0       0         0      1
# 24              7          4           0       0         0      1
# 25              7          3           0       0         0      1
# 26              7          2           0       0         0      1
# 27              7          1           0       0         0      1
# 28              7          0           0       0         0      1
# 29              7          1           0       0         0      1
# ...           ...        ...         ...     ...       ...    ...
# 377235         15          5           0       0         0      1
# 377236         15          5           0       0         0      1
# 377237         15          5           0       0         0      1
# 377238         15          5           0       0         0      1
# 377239         15          5           0       0         0      1
# 377240         15          5           0       0         0      1
# 377241         15          5           0       0         0      1
# 377242         15          5           0       0         1      0
# 377243         15          5           0       0         1      0
# 377244         15          5           0       0         1      0
# 377245         15          5           0       0         1      0
# 377246         15          5           0       0         1      0
# 377247         15          5           0       0         1      0
# 377248         15          5           0       0         1      0
# 377249         15          5           0       0         1      0
# 377250         15          5           0       0         1      0
# 377251         15          5           0       0         1      0
# 377252         15          5           0       0         1      0
# 377253         15          5           0       1         0      0
# 377254         15          5           0       1         0      0
# 377255         15          5           0       1         0      0
# 377256         15          5           0       1         0      0
# 377257         15          5           0       1         0      0
# 377258         15          5           0       1         0      0
# 377259         15          5           0       1         0      0
# 377260         15          5           1       0         0      0
# 377261         15          5           1       0         0      0
# 377262         15          5           1       0         0      0
# 377263         15          5           1       0         0      0
# 377264         15          5           1       0         0      0
#
#         datetime_label  temperature     pressure   humidity
# 0                   14    -2.446930  1018.340389  55.292811
# 1                   15    -2.270506  1018.574498  53.275542
# 2                   16    -2.016952  1018.733522  50.109216
# 3                   17    -1.761945  1018.895087  46.947844
# 4                   18    -1.509102  1019.059065  43.782434
# 5                   19    -1.808341  1019.301666  44.244828
# 6                   20    -2.107474  1019.550670  44.702605
# 7                   21    -2.409933  1019.795085  45.164920
# 8                   22    -2.672708  1020.214293  44.964295
# 9                   23    -2.937088  1020.634392  44.762753
# 10                  24    -3.198235  1021.058500  44.558197
# 11                  25    -0.904161  1021.243781  38.154315
# 12                  26     1.395420  1021.430428  31.748337
# 13                  27     3.689574  1021.620663  25.345762
# 14                  28     4.520366  1021.096656  24.234061
# 15                  29     5.357972  1020.577211  23.120098
# 16                  30     6.188658  1020.058058  22.007686
# 17                  31     4.133634  1019.848006  28.779991
# 18                  32     2.073834  1019.632111  35.555029
# 19                  33     0.014272  1019.420484  42.327335
# 20                  34    -0.636221  1019.448389  47.470644
# 21                  35    -1.284060  1019.471731  52.608683
# 22                  36    -1.938404  1019.500737  57.752703
# 23                  37    -2.206413  1019.128084  60.596263
# 24                  38    -2.475523  1018.754665  63.443937
# 25                  39    -2.744218  1018.384689  66.289125
# 26                  40    -3.034135  1018.245223  66.712677
# 27                  41    -3.324361  1018.106476  67.132303
# 28                  42    -3.613697  1017.967010  67.556621
# 29                  43    -3.858870  1017.677185  68.526464
# ...                ...          ...          ...        ...
# 377235           11638    17.403420  1009.684769  48.378931
# 377236           11638    17.495227  1007.368375  46.587567
# 377237           11638    17.792596   989.562007  40.288150
# 377238           11638    17.237221   996.727567  40.330290
# 377239           11638    17.742456  1006.717690  46.029596
# 377240           11638    17.418378  1000.954626  49.150658
# 377241           11638    17.823077  1001.901242  47.458855
# 377242           11638    17.070224  1003.368911  45.547971
# 377243           11638    17.364604  1009.731388  45.400123
# 377244           11638    17.245723  1010.250105  44.071039
# 377245           11638    16.000000  1011.195821  49.098627
# 377246           11638    16.128701  1009.981871  52.709100
# 377247           11638    17.921220   994.777562  41.336375
# 377248           11638    17.318635   990.330620  45.623078
# 377249           11638    14.174459   999.850312  60.602492
# 377250           11638    15.038947   996.180027  58.280411
# 377251           11638    15.900454   994.768464  57.983660
# 377252           11638    13.298125   953.485682  62.725408
# 377253           11638    17.973609   980.066214  42.177166
# 377254           11638    13.482225   946.649873  46.777869
# 377255           11638    15.994735   982.065155  52.608552
# 377256           11638    14.250760   999.736882  56.953275
# 377257           11638    16.084896  1011.928510  49.079677
# 377258           11638    17.734898  1010.379366  45.788066
# 377259           11638    17.000000  1003.384066  47.539141
# 377260           11638    18.616852  1008.726340  41.980368
# 377261           11638    18.041472  1008.762514  41.233642
# 377262           11638    17.679270  1007.201787  43.419466
# 377263           11638    17.982888  1008.609438  43.677765
# 377264           11638    16.939395  1009.927938  52.250530
#
# [377265 rows x 23 columns]

# %%
aq_df.to_csv(os.path.join(output_folder, 'train_set.zip'), compression='zip')
